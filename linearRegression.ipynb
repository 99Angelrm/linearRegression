# %%
#import Section
import torch
#nn module
import torch.nn as

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        #One Neuron one input and one output
        self.linear = 
    # Forward pass
    def forward(self, x):
        return self.

# %%
if __name__ == "__main__":
    x_train = torch.unsqueeze(torch.linspace(-1, 1, 100), dim=1)
    # y = 2 * x + 1 + noise
    y_train =  0.2 * torch.rand(x_train.size())

    model = NeuralNetwork()
    ##NN loss function
    criterion = MSELoss()
    #Learning rate 0.01
    optimizer = torch.optim.SGD(model.parameters())

    #epochs
    for epoch in range():
        optimizer.zero_grad()
        outputs = model(x_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()

        #each 10 epochs print the loss
        if (epoch+1) == 0:
            print(f'Epoch [{epoch+1}/100], Loss: {loss.item():.4f}')

# %%
import matplotlib.pyplot as plt

with torch.no_grad():
    predictions = model(x_train)

plt.scatter(x_train.numpy(), y_train.numpy(), label='Data')
plt.plot(x_train.numpy(), predictions.numpy(), color='red', label='Fitted Line')
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), ".pth")

# %%
params = model.state_dict()
neuron_weights = params['linear.weight']
neuron_bias = params['linear.bias']
print(f"Learned weight: {neuron_weights.item():.4f}, Learned bias: {neuron_bias.item():.4f}")
